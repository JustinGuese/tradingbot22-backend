# %%
# !pip install alpaca-py

# %%
from alpaca.trading.client import TradingClient
trading_client = TradingClient('', '', paper=True)
account = trading_client.get_account()
account
# Out:
# {   'account_blocked': False,
#     'account_number': 'PA2ELGHCZB87',
#     'accrued_fees': '0',
#     'buying_power': '200000',
#     'cash': '100000',
#     'created_at': datetime.datetime(2020, 5, 27, 18, 25, 5, 927058, tzinfo=datetime.timezone.utc),
#     'crypto_status': <AccountStatus.ACTIVE: 'ACTIVE'>,
#     'currency': 'USD',
#     'daytrade_count': 0,
#     'daytrading_buying_power': '0',
#     'equity': '100000',
#     'id': UUID('3fd858c5-701d-4d5b-b525-58fc779fb63a'),
#     'initial_margin': '0',
#     'last_equity': '100000',
#     'last_maintenance_margin': '0',
#     'long_market_value': '0',
#     'maintenance_margin': '0',
#     'multiplier': '2',
#     'non_marginable_buying_power': '98000',
#     'pattern_day_trader': True,
#     'pending_transfer_in': '0',
#     'pending_transfer_out': None,
#     'portfolio_value': '100000',
#     'regt_buying_power': '200000',
#     'short_market_value': '0',
#     'shorting_enabled': True,
#     'sma': '0',
#     'status': <AccountStatus.ACTIVE: 'ACTIVE'>,
#     'trade_suspended_by_user': False,
#     'trading_blocked': False,
#     'transfers_blocked': False}

# %%
from alpaca.trading.enums import AssetClass
from alpaca.trading.requests import GetAssetsRequest


search_params = GetAssetsRequest(asset_class=AssetClass.US_EQUITY)

assets = trading_client.get_all_assets(search_params)
assets
# Out:
# [{   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NYSE: 'NYSE'>,
#      'fractionable': True,
#      'id': UUID('b8297826-48c8-4216-a151-bb31ffcd19e0'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'RR Donnelley & Sons Co.',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'RRD',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NYSE: 'NYSE'>,
#      'fractionable': False,
#      'id': UUID('fff941e1-28d2-460a-850d-dc1b46d8a9df'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Deutsche Bank Contingent Capital Trust II 6.55% Trust Preferred '
#              'Securities Called',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'DXB.CL',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('801ac061-9a2d-445f-b9a0-165fad80729c'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Ibstock PLC Ordinary Shares (United Kingdom)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'IBJHF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('40b4a124-377a-4931-9ef4-d7d38a814e57'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'UNIVERSAL IBOGAINE INC Common Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'IBOGF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('3fca0c88-9ab2-4ec8-a19f-d35b2a104f41'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'iBrands Corporation Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'IBRC',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('720b8845-e8ab-4d85-8248-05897e237e40'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Integrated Business Systems and Services, Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'IBSS',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('879885ad-766b-4e86-af02-0a30206d3e81'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Ibex Technologies Inc Common Ordinary Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'IBXNF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NYSE: 'NYSE'>,
#      'fractionable': False,
#      'id': UUID('24b1910b-50ed-4aab-bd64-ecd41f75b8ca'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Lydall, Inc.',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'LDL',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('a73b51c6-4a99-4a86-9c5d-3522566e0936'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'IBITX Software Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'IBXS',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('e04f2cc4-a969-4f9b-b39f-562fbe7351fd'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Imagion Biosystems Ltd. Ordinary Shares (Australia)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'IBXXF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': False,
#      'id': UUID('bfabb385-b6cf-4507-9da4-a3d3526ca778'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'CONTRA LIGAND PHARMACE',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': '532CNT011',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('09994c48-683f-4553-bf36-d4243957a2f3'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Aztec Minerals Corp Ordinary Shares (Canada)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'AZZTF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.ARCA: 'ARCA'>,
#      'fractionable': False,
#      'id': UUID('4c6e7dda-bfda-4381-9f92-90f85b9f136c'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'iShares Currency Hedged MSCI Australia ETF',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'HAUD',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': False,
#      'id': UUID('608810ad-8342-4356-8367-272aed831d08'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'BioPlus Acquisition Corp. Class A Ordinary Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'BIOS',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': False,
#      'id': UUID('c4ad7743-863a-4fa3-a4b6-667cc7c47002'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'iShares Trust iShares MSCI Japan Equal Weighted ETF',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'EWJE',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NYSE: 'NYSE'>,
#      'fractionable': False,
#      'id': UUID('f751f7d1-2360-402d-a139-48e9d9396994'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'The Gabelli Global Small and Mid Cap Value Trust 5.450% Series A '
#              'Cumulative Preferred Shares (Liquid',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'GGZ.PRA',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('7069a1e6-7226-4445-92cc-fc73c5b35094'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Boohoo Group Plc American Depositary Receipts - Unsponsored',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'BHOOY',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('9d1ddd6a-474e-4172-9ae0-1b560d6acb8b'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Conrad Industries, Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'CNRD',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('83f8b8ab-f13a-41d3-91b2-cd8cac8fc095'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'EUROAPI SA Common Shares (France)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'EAPIF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('cbc2eba9-818a-4c67-8fa1-2bbe4fde526d'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'First Community Corporation (TN) Preferred Series A',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'FCCTP',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('364559b3-a48f-4bc0-8910-c19b44a37229'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Fertoz Ltd Ordinary Shares (Australia)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'FTZZF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('0db6577e-ab30-4548-8a05-146ca29a9345'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'HUMBL, Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'HMBL',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('7217a59f-811f-4c6b-919d-d77dfd7d3847'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'ISHARES III PLC INTERMEDIATE CREDIT BOND UCITS ETF (Ireland)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'ICBIF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('fb33ba94-db44-4734-8531-447b967d85ba'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'IMD Companies, Inc.  Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'ICBU',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('438af5e4-163f-4b95-bbd7-49f6dcb3bc69'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Intercare DX, Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'ICCO',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': False,
#      'id': UUID('d3461773-97cb-49b0-b2cc-96730af827a2'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'BroadVision, Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'BVSN',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('6da9045b-ad3c-4e78-b60f-44d788d4a57b'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'iCoreConnect, Inc. Common Stock (United States)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'ICCT',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.ARCA: 'ARCA'>,
#      'fractionable': False,
#      'id': UUID('a09b42c7-6051-4150-866b-1d60c988927f'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Innovation Trade War ETF',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'TWAR',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('3c74d9b0-9ef4-46fd-ba84-5ac28191cffe'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Boss Energy Ltd Ordinary Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'BQSSF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('495ee5fa-d181-4237-9969-02d72161c270'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Dividend Select 15 Corp Ordinary Shares (Canada)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'DVVDF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('9eba1e16-f394-4cdb-aca8-32b038b1479a'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Feishang Anthracite Resources Ltd. Ordinary Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'FSHRF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('397b48aa-b5ab-4689-9fd2-b88e5db0d643'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Global Hemp Group Inc Common Shares (Canada)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'GBHPF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('7d550a16-8e9b-467d-bd80-13504e18652d'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'AU MIN AFRICA PTY, LTD. (South Africa)Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'GRYEF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('36e7cf17-792a-4b93-8613-335a2d9227df'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Helix Wind, Corp. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'HLXW',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('d1f755e5-ca0a-446b-9358-bc1a91007deb'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Ishares IV PLC Accum Ptg Shares ETF (Ireland)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'IAACF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('d88267c4-17a3-4160-912a-df3f76fd2352'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'ISHARES III PLC BARCLAYS GBL AGGREGATE BD USD Exchange Traded '
#              'Fund',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'IBGAF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('eac3b560-9e54-449c-884b-48bffe9b1c8e'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'iShares Canadian Real Return Bond Index ETF (Canada)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'ICDXF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('2e794c70-9e01-4040-b656-c9041bf01516'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Ishares Canadian Hybrid Corporate Bond Index ETF (Canada)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'ICDZF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('a41853fb-304d-42b9-a3ac-d5c818a54c50'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'India Capital Growth Fund Ltd. Shs (Guernsey)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'ICGFF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('a1059231-a972-4bac-ba34-b431f7d1f8ed'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Image Chain Group Limited, Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'ICGL',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('ce1738f9-eef1-4a40-85ba-e2778045c1f2'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Intermediate Cap Grp Plc Ordinary Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'ICGUF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('5a5a32bd-8e97-4fb4-b0e6-8edaba09818e'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Industrias Ch Sa de Cv Ich Shares B',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'ICHBF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': True,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('348b8fca-353b-42ea-ad78-442dc1b2e165'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Intercontinental Hotels Group Ordinary Shares',
#      'price_increment': None,
#      'shortable': True,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'ICHGF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('73722962-8b49-48cc-8d5e-4d6319b2c0eb'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Ichigo Group Holdings Co Ltd Ordinary Shares (Japan)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'ICHIF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('4fa71e23-c1ed-435f-ac19-6ab457ed8b94'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'INTERCLOUD SYS INC Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'ICLD',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('7e41bc9c-f9cc-42f5-b04a-bed5457dd4a2'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Croghan Bancshares, Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'CHBH',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('1cfbe371-4b8b-47ee-a37c-73e0e796a80a'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Elior Unsponsored American Depository Receipt (France)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'ELORY',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': False,
#      'id': UUID('dc9754f5-1539-471a-bc33-f313a49d6fc0'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Gores Metropoulos II, Inc. Unit',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'GMIIU',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NYSE: 'NYSE'>,
#      'fractionable': True,
#      'id': UUID('7a765658-510c-4f2b-8dc2-cb65465a65e3'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'HILL-ROM HOLDINGS, INC.',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'HRC',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': True,
#      'id': UUID('7edf3407-1e6f-48d7-89a7-7f95da90628b'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'SOC Telemed, Inc. Class A Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'TLMD',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': False,
#      'id': UUID('afd87b2d-4f7c-433c-a31f-83581b007de2'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'FinServ Acquisition Corp. Unit',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'FSRVU',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('e38111c9-ec60-4458-8b0a-3eb994990c60'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'General Store International Corporation (The) Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'GSIL',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('494756f7-0891-4e45-a195-f692e3d0175b'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Icon Media Holdings, Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'ICNM',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('906d129a-a255-45b4-8fdc-1707b2265612'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Icon Energy LTd Ordinary Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'ICNOF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('4ced38be-7774-4f55-8aae-e85cb704e371'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Icoa Inc  Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'ICOA',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NYSE: 'NYSE'>,
#      'fractionable': False,
#      'id': UUID('31a36166-5999-4af0-bd7f-8c67c07e4971'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'SEMGROUP CORPORATION',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'SEMG',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('04b24603-57c7-4a06-823f-6efb0ca979a1'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Inscape Corporation Ordinary Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'ICPBQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': True,
#      'id': UUID('2d723bc9-839b-4e3b-8322-c0e282781fdf'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Sharps Compliance Corp. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'SMED',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('486458c5-d517-4d0e-bd8f-49bc231cac8f'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'International Card Establishment, Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'ICRD',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': False,
#      'id': UUID('1d2cba9d-a119-4f7d-a646-26a5283518e5'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'CleanTech Acquisition Corp. Rights',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'CLAQR',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': False,
#      'id': UUID('320c43a2-b5e9-4fa0-a006-d6ccda02dbdc'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Riverview Financial Corporation Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'RIVE',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': False,
#      'id': UUID('dd5c2011-d8d0-41e7-be0f-39ff77563571'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Perspectum Group Plc American Depositary Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'SCAN',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.BATS: 'BATS'>,
#      'fractionable': False,
#      'id': UUID('0a8d055a-df47-498d-b8e7-ad75455cec6c'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Pacer Salt High truBeta US Market ETF',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'SLT',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('79572ad5-dcc4-41c4-894e-3ac4daace1b8'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Alpha Network Alliance Ventures Inc. Com',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'ANAV',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': False,
#      'id': UUID('b2f40ab0-164f-4636-84d5-bc235201cab5'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Founder SPAC Units',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'FOUNU',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NYSE: 'NYSE'>,
#      'fractionable': False,
#      'id': UUID('a8e9ab04-84cc-458b-82b8-63f0891a4409'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Northern Genesis Acquisition Corp. Units, each consisting of one '
#              'share of common stock and one-half',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'NGA.U',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.AMEX: 'AMEX'>,
#      'fractionable': False,
#      'id': UUID('a26fc678-2036-465c-a7af-4b65e7e07701'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Adara Acquisition Corp.',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'ADRA',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': True,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': True,
#      'id': UUID('2fca82e4-0edd-4200-92c3-3f7ef4ae8c57'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Coherent Corp. Common Stock',
#      'price_increment': None,
#      'shortable': True,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'COHR',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.ARCA: 'ARCA'>,
#      'fractionable': False,
#      'id': UUID('fb8d91dc-62dc-489c-8d47-93261d9e370f'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': '',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'DXJF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': False,
#      'id': UUID('7867b672-7e6e-4368-be9d-591a6df2b8bf'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Radius Health, Inc. Contingent Value Rights Expires December 31, '
#              '2025',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': '750CVR011',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('285f3eca-39c9-426c-b999-ab572539ad3e'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'First Bitcoin Capital Corp. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'BITCF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('e5c9d529-bc6c-46c4-9878-a675264e04a9'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Enbridge Inc Cum Redeemable Pref Shs Ser L (Canada)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'EBBNF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('b822ff34-01b8-4a74-b1c7-1fbdb0fb6c9a'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'ERICKSON INC NEW COM',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'EKSN',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('d0f2e4da-4724-4594-b2a2-3e05e4d02fd3'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Green For Energy, Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'GRGG',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('8c800b8b-5639-4f84-bedc-1cbe6207a3cd'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Goviex Uranium Inc Ordinary Shares Cl A (Canada)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'GVXXF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('f7bf8983-e945-41f5-afc4-0dac4fa0818b'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'ICTS International N.V. Common Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'ICTSF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': False,
#      'id': UUID('fc226203-af30-405a-bbe9-7f8700295a88'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Synacor, Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'SYNC',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NYSE: 'NYSE'>,
#      'fractionable': False,
#      'id': UUID('745a6128-cb91-46ed-afcb-d1ac2095b294'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Alussa Energy Acquisition Corp.',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'ALUS.U',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': False,
#      'id': UUID('4aa120ad-5a0e-4733-9ed7-c0ee8050fd43'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'GigCapital4, Inc. Unit',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'GIGGU',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('6105c6d7-706e-4081-8137-7a0f555011bb'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Idarado Mining Co Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'IDAM',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('35abeae3-1939-4ed3-a5b1-d8ff1e264ecd'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'INDUSTRIAS BACHOCO SAB DE CV Ordinary Shares B (Mexico)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'IDBHF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('8115d390-4c6b-49de-8333-09dc1ca00d01'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Digatrade Financial Corp. Common Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'DIGAF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NYSE: 'NYSE'>,
#      'fractionable': False,
#      'id': UUID('492d505f-20f7-4c67-baa0-954adc075ea1'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'VIVINT SOLAR, INC.',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'VSLR',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('eafbf33d-5bee-4cd3-b1de-8febf3a782ed'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Economic Investment Trust Ltd. Ordinary Shares (Canada)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'ECVTF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('75fc45ee-92cb-4f88-962e-f063f836079a'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Eurogas International Common Stock (Barbados)',
# ...
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('dd0deb2b-e130-41e3-9265-50338c25a458'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Jasmine International Public Co Ltd Units Non-Voting Depositary '
#              'Receipt (Thailand)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'JASUF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('81bbb465-2e15-45f6-b1bb-0fc0eaf34811'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Jaxsta Ltd Ordinary Shares (Australia)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'JAXAF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': True,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('756c6ce5-aa79-4d0c-9775-a37b4c6614b3'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Julius Baer Gruppe AG Zuerich Namen - AKT (Switzerland)',
#      'price_increment': None,
#      'shortable': True,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'JBARF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('31c4e660-f6eb-49d4-b47d-a8985fe5a3c7'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'American Graphite Technologies Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'AGIN',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('0d231b38-c85c-4f83-a0e4-5b2c43dcc06f'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'OLYMPIO METALS LTD Ordinary Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'COPGF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('a4cebed7-acda-418f-9634-0668a686a001'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'DRONE GUARDER, INC. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'DRNG',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('06104211-d4b1-48b7-a7a8-7e6461231acd'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'EL.EN. SPA FIRENZE Ordinary Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'ELEAF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('d39b77ea-80b7-46ce-8c69-f1f16d944db1'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Furukawa Elec Ltd Ordinary Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'FUWAF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('122b2ed2-a81c-4838-9c0d-71073af7ea1c'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'FutureWorld Corp. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'FWDG',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('fbb461c2-1a0b-47a8-9f62-5b57a6b075d8'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'INVESCO MKTS PLC INVESCO COMMUNICATIONS S&P US SELECT SECTOR '
#              'UCITS ETF ACC Exchange Traded Fund',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'ICMNF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('be8d51b0-b755-4c6d-9f75-87d96a99e90b'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Jollibee Foods Corporation Ordinary Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'JBFCF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('03d264c6-a427-40c3-a087-a3fdf6897435'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'JB HI-FI LTD American Depositary Receipts - Unsponsored '
#              '(Australia)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'JBHHY',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('4e6ab611-3e22-4237-b671-f6a7386a534d'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Better Environment Concepts, Inc. Common Stock ($0.01 Par Value)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'BEEN',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('dfcfcde7-6f9c-4d2a-a32c-9c463952a316'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'DNAPrint Genomics, Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'DNAG',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('f06f9abd-9ff7-4267-beeb-99bf4ccfcbe0'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'ENBRIDGE INC Re Pref Shs Ser 5 (Canada)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'EBGEF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': True,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('655d8f5f-ab72-4849-9415-77cb2d070c00'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Elmo Software Ltd. Ordinary Shares Fully Paid (Australia)',
#      'price_increment': None,
#      'shortable': True,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'ELMFF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('cc64b481-b2ea-45c7-a6e0-1ce6a27b59ba'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Eros Resources Corp. Ordinary Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'EROSF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('124b2c62-2d21-44c5-871c-9886558acbb3'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'JB Hi-Fi Limited Ordinary Shares (Australlia)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'JBHIF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('53e00b89-5639-40db-8a70-3aaac879aa74'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'SWISSCANTO ETF PRECIOUS METAL PHYSICAL GOLD SHS HLDGS KLASSE - A- '
#              '(Switzerland)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'JBPCF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('a3d7fbd8-f7aa-45f8-8399-a44bccdcd834'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'BEAM COMMUNICATIONS HLDGS LTD ORDINARY FULLY PAID (Australia)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'BCCHF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('c9cea21f-cb92-4fef-a07a-3f54627f916d'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Biotage AB Ordinary Shares A (Sweden)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'BITGF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('5e030058-9db5-4455-b4ba-6d6f9e8d3ba1'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Dolphin Capital Investors Ltd Reg  Shares (British Virgin '
#              'Islands)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'DOLHF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('689bd6c7-2d79-476a-80b5-a4dc795ae71a'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Discovery Silver Corp Ordinary Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'DSVSF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': True,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('ac937f4c-8f06-4711-bee1-5ffbf56c5585'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'ENERGEAN OIL AND GAS PLC Ord GBP0.01 (United Kingdom)',
#      'price_increment': None,
#      'shortable': True,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'EERGF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('ec23820b-bdea-44ad-be06-2501e6470e63'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Ehouse Global, Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'EHOS',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('0b1da299-f035-4c91-93d8-423611e01a39'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Mensa Mining Corp. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'EQBM',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('f97a10aa-ba3e-48d5-b14e-3fe591ad285c'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Fit After Fifty, Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'FTFY',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('1b5a9e2a-5728-4457-ab3e-fc2d8eb01bdc'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'GTI ENERGY LTD Ordinary Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'GTRIF',
#      'tradable': False},
#  ...]

# %%
from alpaca.trading.requests import MarketOrderRequest
from alpaca.trading.enums import OrderSide, TimeInForce

# preparing orders
market_order_data = MarketOrderRequest(
                    symbol="TQQQ",
                    qty=1,
                    side=OrderSide.BUY,
                    time_in_force=TimeInForce.DAY
                    )

# Market order
market_order = trading_client.submit_order(
                order_data=market_order_data
               )
market_order
# Out:
# {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#     'asset_id': UUID('dce2ac30-c928-4416-be25-2213d057f30a'),
#     'canceled_at': None,
#     'client_order_id': 'ca35bd7b-4c5c-4fb4-9263-c414ec77f4d3',
#     'created_at': datetime.datetime(2023, 2, 4, 11, 52, 49, 366429, tzinfo=datetime.timezone.utc),
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': UUID('e22b268f-f4df-46a2-91bf-14778e93ca3a'),
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': <OrderClass.SIMPLE: 'simple'>,
#     'order_type': <OrderType.MARKET: 'market'>,
#     'qty': '1',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': <OrderSide.BUY: 'buy'>,
#     'status': <OrderStatus.ACCEPTED: 'accepted'>,
#     'stop_price': None,
#     'submitted_at': datetime.datetime(2023, 2, 4, 11, 52, 49, 365884, tzinfo=datetime.timezone.utc),
#     'symbol': 'TQQQ',
#     'time_in_force': <TimeInForce.DAY: 'day'>,
#     'trail_percent': None,
#     'trail_price': None,
#     'type': <OrderType.MARKET: 'market'>,
#     'updated_at': datetime.datetime(2023, 2, 4, 11, 52, 49, 366429, tzinfo=datetime.timezone.utc)}

# %%
from alpaca.trading.requests import GetOrdersRequest
from alpaca.trading.enums import OrderSide, QueryOrderStatus
# params to filter orders by
request_params = GetOrdersRequest(
                    status=QueryOrderStatus.OPEN,
                    # side=OrderSide.SELL
                 )

# orders that satisfy params
orders = trading_client.get_orders(filter=request_params)
orders
# Out:
# [{   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('dce2ac30-c928-4416-be25-2213d057f30a'),
#      'canceled_at': None,
#      'client_order_id': 'ca35bd7b-4c5c-4fb4-9263-c414ec77f4d3',
#      'created_at': datetime.datetime(2023, 2, 4, 11, 52, 49, 366429, tzinfo=datetime.timezone.utc),
#      'expired_at': None,
#      'extended_hours': False,
#      'failed_at': None,
#      'filled_at': None,
#      'filled_avg_price': None,
#      'filled_qty': '0',
#      'hwm': None,
#      'id': UUID('e22b268f-f4df-46a2-91bf-14778e93ca3a'),
#      'legs': None,
#      'limit_price': None,
#      'notional': None,
#      'order_class': <OrderClass.SIMPLE: 'simple'>,
#      'order_type': <OrderType.MARKET: 'market'>,
#      'qty': '1',
#      'replaced_at': None,
#      'replaced_by': None,
#      'replaces': None,
#      'side': <OrderSide.BUY: 'buy'>,
#      'status': <OrderStatus.ACCEPTED: 'accepted'>,
#      'stop_price': None,
#      'submitted_at': datetime.datetime(2023, 2, 4, 11, 52, 49, 365884, tzinfo=datetime.timezone.utc),
#      'symbol': 'TQQQ',
#      'time_in_force': <TimeInForce.DAY: 'day'>,
#      'trail_percent': None,
#      'trail_price': None,
#      'type': <OrderType.MARKET: 'market'>,
#      'updated_at': datetime.datetime(2023, 2, 4, 11, 52, 49, 366429, tzinfo=datetime.timezone.utc)}]
